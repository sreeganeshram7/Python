# %%
# !python File1.py
# Out:
# File1 is being run directly
# File1 is being imported

# %%
import File1
print("File2 __name__ = %s" %__name__)
if __name__ == "__main__":
    print("File2 is being run directly")
else:
    print("File2 is being imported")
# Out:
# File1 is being run directly
# File1 is being imported
# File2 __name__ = __main__
# File2 is being run directly

# %%
# __name__--> built in variable

# %%
def my_function():
    print("I am inside function")
 
my_function()
# Out:
# I am inside function

# %%
def my_function():
    print("I am inside function")
 
if __name__ == "__main__":
    my_function()
# Out:
# I am inside function

# %%
import File7
# Out:
# I am inside function

# %%
import File3

# %%
# File Handling

# %%
f = open("sample.txt")
f
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f = open("sample.txt","rt")
f
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='rt' encoding='cp1252'>

# %%
print(f.read())
# Out:
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# "a" - Append - Opens a file for appending, creates the file if it does not exist
# "w" - Write - Opens a file for writing, creates the file if it does not exist
# "x" - Create - Creates the specified file, returns an error if the file exists

# %%
with open("sample.txt")as f1:
          print(f1.read())
# Out:
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# "a" - Append - Opens a file for appending, creates the file if it does not exist
# "w" - Write - Opens a file for writing, creates the file if it does not exist
# "x" - Create - Creates the specified file, returns an error if the file exists

# %%
with open("sample.txt")as f1:
          print(f1.readline()) 
          print(f1.readline()) 
          print(f1.readline()) 
f1.close()
# Out:
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist

# %%
with open("sample.txt")as f1:
    for x in f1:
        print(x)
f1.close()
# Out:
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# "x" - Create - Creates the specified file, returns an error if the file exists

# %%
with open("sample.txt","a")as f1:
    f1.write("changes made")

# %%
with open("sample.txt")as f1:
          print(f1.read())
# Out:
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# "a" - Append - Opens a file for appending, creates the file if it does not exist
# "w" - Write - Opens a file for writing, creates the file if it does not exist
# "x" - Create - Creates the specified file, returns an error if the file existsGaneshGaneshGaneshGaneshGaneshchanges made

# %%
with open("sample1.txt","x")as f1:
    f1.write("This is a new python file")

# %%
with open("sample1.txt")as f1:
          print(f1.read())
# Out:
# This is a new python file

# %%
# how to use w how to write inside file use w
