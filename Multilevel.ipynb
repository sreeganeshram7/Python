# %% [markdown]
# ## implement multilevel inheritance with examples one grandparent,one parent,one child

# %%
from grandClass import Grandparent,Parents,Childs

# %%
obj=Grandparent("petchi",86)
obj1=Parents("muthu",50)
obj2=Childs("moorthi",22)

# %%
print(obj.grand())
# Out:
# GrandParent name is petchi his age is 86

# %%
print(obj1.parents())
# Out:
# Parent name is muthu his age is 50

# %%
print(obj2.childs())
# Out:
# My name is moorthi my age is 22
