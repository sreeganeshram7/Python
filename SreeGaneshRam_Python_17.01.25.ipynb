# %% [markdown]
# # Question 1  [10 Marks]
# ## Problem Statement:
# ### Create a class ProductLoader that performs the following operations:
# #### 1.	Loads Product.csv file with comprehensive error handling using try-except-finally block
# #### 2.	Implements string manipulation to convert all ProductName values to uppercase
# #### 3.	Creates a function using loops to filter products where Price > 20000 AND Rating > 4.0
# #### 4.	Returns filtered products as a list of dictionaries containing ProductID, ProductName, Price
# #### 5.	Implements custom exception LowRatingError that is raised when any product has Rating < 2.0

# %%
import numpy as np
import pandas as pd

# %%
#1
class ProductLoader:
    try:
        df=pd.read_csv("Product(in).csv")
        print(df)
    except FileNotFoundError:
        print(f"Product {Product.csv} file not found")
    finally:
        print("File Uploaded SuccessFully")
# Out:
#       ProductID   ProductName         Category     Price  StockQuantity  \
# 0          2001  Product_2001      Accessories  19039.74            256
# 1          2002  Product_2002      Electronics  47560.36            278
# 2          2003  Product_2003      Electronics  36733.70            150
# 3          2004  Product_2004      Accessories  30133.59            283
# 4          2005  Product_2005        Wearables   8222.92            425
# ...         ...           ...              ...       ...            ...
# 1045       3046  Product_3046    Smart Devices  30985.23            118
# 1046       3047  Product_3047      Electronics  12031.49             45
# 1047       3048  Product_3048      Accessories   1707.84            241
# 1048       3049  Product_3049  Home Appliances  43569.89            238
# 1049       3050  Product_3050        Wearables   1552.84            362
#
#       SupplierID  WarrantyMonths  Rating
# 0             36              12     3.6
# 1              3              12     4.9
# 2              9               6     4.3
# 3              8              12     2.5
# 4             33               6     3.4
# ...          ...             ...     ...
# 1045          41               6     2.2
# 1046           1              12     3.3
# 1047           8               6     2.3
# 1048          23              24     3.8
# 1049          38              24     4.8
#
# [1050 rows x 8 columns]
# File Uploaded SuccessFully

# %%
df=pd.read_csv("Product(in).csv")
print(df)
# Out:
#       ProductID   ProductName         Category     Price  StockQuantity  \
# 0          2001  Product_2001      Accessories  19039.74            256
# 1          2002  Product_2002      Electronics  47560.36            278
# 2          2003  Product_2003      Electronics  36733.70            150
# 3          2004  Product_2004      Accessories  30133.59            283
# 4          2005  Product_2005        Wearables   8222.92            425
# ...         ...           ...              ...       ...            ...
# 1045       3046  Product_3046    Smart Devices  30985.23            118
# 1046       3047  Product_3047      Electronics  12031.49             45
# 1047       3048  Product_3048      Accessories   1707.84            241
# 1048       3049  Product_3049  Home Appliances  43569.89            238
# 1049       3050  Product_3050        Wearables   1552.84            362
#
#       SupplierID  WarrantyMonths  Rating
# 0             36              12     3.6
# 1              3              12     4.9
# 2              9               6     4.3
# 3              8              12     2.5
# 4             33               6     3.4
# ...          ...             ...     ...
# 1045          41               6     2.2
# 1046           1              12     3.3
# 1047           8               6     2.3
# 1048          23              24     3.8
# 1049          38              24     4.8
#
# [1050 rows x 8 columns]

# %%
#2

# %%
#3/4
def filter_products(df):
    result={}
    filter=df[df['Price']>20000] & df[df['Rating']>4.0]
    result=filter.df({"ProductID","ProductName","Price"})
    return result

# %%
#5
class LowRatingError(Exception):
    pass
def rating(df):
    try:
        filtered=df[df['Rating']<2.0]
        print("filtered")
    except LowRatingError:
        if df[df['Rating']<2.0]:
            print("Rating Success")
        else:
            raise LowRatingError(f" Rating need more than 2.0")

# %% [markdown]
# # Question 2  [10 Marks]
# ## Problem Statement:
# ### Write a program that analyzes Sales.csv data using Python collections:
# #### 1.	Load Sales.csv into Pandas DataFrame
# #### 2.	Extract unique PaymentMethod values and convert to immutable tuple
# #### 3.	Use dictionary comprehension to count total transactions per Region
# #### 4.	Implement function with explicit loops to calculate total SaleAmount for each payment method
# #### 5.	Use if-elif-else branching to categorize sales:
# #### High: SaleAmount > 50,000
# #### Medium: 10,000 ≤ SaleAmount ≤ 50,000
# #### Low: SaleAmount < 10,000
# #### 6.	Return dictionary with payment methods and their totals

# %%
#1
df1=pd.read_csv("Sales(in).csv")
df1
# Out:
#       SaleID   SaleDate CustomerID  ProductID  QuantitySold  SaleAmount  \
# 0       5001   7/4/2024  CUST_6438       2179             3    83085.91
# 1       5002  4/22/2024  CUST_5476       2900             1    51306.03
# 2       5003  9/16/2024  CUST_3039       2241             3    62403.89
# 3       5004  2/10/2022  CUST_7029       2486             3    48296.47
# 4       5005  5/21/2023  CUST_8159       2430             4    48337.73
# ...      ...        ...        ...        ...           ...         ...
# 1095    6096  8/17/2024  CUST_5877       2700             7    11260.04
# 1096    6097  1/27/2022  CUST_1528       2728             9    70538.13
# 1097    6098   8/9/2022  CUST_8368       2598             5    30646.31
# 1098    6099   1/2/2023  CUST_5305       2766             2    27616.83
# 1099    6100   4/8/2021  CUST_6711       2218             7    99799.77
#
#      PaymentMethod   Region
# 0      Credit Card    South
# 1       Debit Card     West
# 2      Net Banking     West
# 3       Debit Card    South
# 4      Net Banking    North
# ...            ...      ...
# 1095    Debit Card  Central
# 1096           UPI    South
# 1097   Net Banking     West
# 1098   Credit Card  Central
# 1099   Credit Card     West
#
# [1100 rows x 8 columns]

# %%
#2
payment=df1.drop_duplicates(subset='PaymentMethod')
payment
# Out:
#    SaleID   SaleDate CustomerID  ProductID  QuantitySold  SaleAmount  \
# 0    5001   7/4/2024  CUST_6438       2179             3    83085.91
# 1    5002  4/22/2024  CUST_5476       2900             1    51306.03
# 2    5003  9/16/2024  CUST_3039       2241             3    62403.89
# 6    5007  1/21/2024  CUST_8204       2877             3    63228.07
# 7    5008   4/6/2022  CUST_7334       2340             8    63693.06
#
#   PaymentMethod Region
# 0   Credit Card  South
# 1    Debit Card   West
# 2   Net Banking   West
# 6           UPI   West
# 7          Cash  North

# %%
payments=payment.to_numpy()
payments
# Out:
# array([[5001, '7/4/2024', 'CUST_6438', 2179, 3, 83085.91, 'Credit Card',
#         'South'],
#        [5002, '4/22/2024', 'CUST_5476', 2900, 1, 51306.03, 'Debit Card',
#         'West'],
#        [5003, '9/16/2024', 'CUST_3039', 2241, 3, 62403.89, 'Net Banking',
#         'West'],
#        [5007, '1/21/2024', 'CUST_8204', 2877, 3, 63228.07, 'UPI', 'West'],
#        [5008, '4/6/2022', 'CUST_7334', 2340, 8, 63693.06, 'Cash',
#         'North']], dtype=object)

# %%
#3
def transactions(df1):
    total=df1.groupby('Region')['SaleID'].count()
    return total.df1({"Total_Transactions":"total"})

# %%
#4
sales=df1.groupby('PaymentMethod')['SaleAmount'].sum()
sales
def total_sales(df1):
    result=sales
    return result

# %%
#5
def sales(df1):
    if df1[df1['SaleAmount']>50000]:
        print("High")
    elif df1[df1['SaleAmount']<10000]:
        print("Low")
    else:
        print("Medium")

# %%
#6
def total_payment(df1):
    result=total_sales(df1)
    return result({"PaymentMethod":"TotalAmount"})

# %% [markdown]
# # Question 3 [10 Marks]
# ## Problem Statement:
# ### Implement a program using functional programming concepts:
# #### 1.	Load SalesChurn.csv into DataFrame
# #### 2.	Define function risk_category(probability) that returns:
# #####	"Critical" if probability > 0.8
# #####	"High" if 0.5 ≤ probability ≤ 0.8
# #####	"Low" if probability < 0.5
# #### 3.	Use list comprehension to apply this function: [risk_category(p) for p in df['ChurnProbability']]
# #### 4.	Create frequency dictionary using collections.Counter to count each risk category
# #### 5.	Raise custom exception InvalidProbabilityError if any probability value is outside [0, 1] range
# #### 6.	Implement proper error handling with try-except

# %%
#1
df2=pd.read_csv("SalesChurn(in).csv")
df2
# Out:
#      CustomerID LastPurchaseDate  InactiveDays  ChurnProbability  \
# 0     CUST_8373       12/17/2023            60              0.18
# 1     CUST_7303        12/2/2020           261              0.89
# 2     CUST_6821        10/3/2022           311              0.44
# 3     CUST_4698         6/1/2022            58              0.14
# 4     CUST_4044        10/2/2020           224              0.76
# ...         ...              ...           ...               ...
# 1015  CUST_8531        9/14/2023           161              0.82
# 1016  CUST_1589       11/30/2022            66              0.89
# 1017  CUST_1538        8/28/2021           161              0.52
# 1018  CUST_3897         5/8/2022           106              0.57
# 1019  CUST_5965         4/3/2022           118              0.67
#
#       CustomerValue  PurchaseFrequency ChurnStatus
# 0          48088.43                  5     Churned
# 1          30332.16                  9     Churned
# 2          28194.03                 46     Churned
# 3           1219.44                 40     At Risk
# 4           4507.01                 14     Churned
# ...             ...                ...         ...
# 1015       24777.10                 20      Active
# 1016        2334.07                 48     Churned
# 1017       26995.01                 48      Active
# 1018       35387.38                 48      Active
# 1019       17288.64                 46      Active
#
# [1020 rows x 7 columns]

# %%
#2
def risk_category(probability):
    if df2[df2['ChurnProbability']>0.8]:
        return "Critical"
    elif df2[df2['ChurnProbability']<0.5]:
        return "Low"
    else:
        return "High"

# %%
#3
def risk_category(p):
    result=[]
    for p in df2['ChurnProbability']:
        result=risk_category(probability)
        return result

# %%
#4
def freq_dict(df2):
    result={}
    for k,v in df2.items():
        result=risk_category(probability)
        return result({"k":"v"})

# %%
#5
class InvalidProbabilityError(Exception):
    pass

# %%
#6
def probability(df2):
    try:
        prob=risk_category(probability)
        print("Probability Value is success")
    except InvalidProbabilityError:
        if df[df['ChurnProbability']<1.0]:
            print("Value is Correct")
        else:
            raise InvalidProbabilityError(f" Please give me correct churn probability value")

# %% [markdown]
# # Question 4  [12 Marks]
# ## Problem Statement:
# ### Create a data analysis program using NumPy:
# #### 1.	Extract Price and StockQuantity columns from Product.csv as NumPy arrays
# #### 2.	Create 2D NumPy array using np.column_stack([prices, stock_quantities])
# #### 3.	Calculate statistical measures using NumPy functions:o	Mean price and mean stock
# #### 	Median values
# #### 	Standard deviation
# #### 	Percentiles: 25th, 50th, 75th for prices
# #### 4.	Use NumPy boolean indexing to filter: products where StockQuantity > 75th percentile
# #### 5.	Implement error handling for data type conversion with ValueError exception
# #### 6.	Return comprehensive statistics dictionary

# %%
#1
price=df['Price'].to_numpy()
price
# Out:
# array([19039.74, 47560.36, 36733.7 , ...,  1707.84, 43569.89,  1552.84])

# %%
stock=df['StockQuantity'].to_numpy()
stock
# Out:
# array([256, 278, 150, ..., 241, 238, 362])

# %%
#2
arr=np.column_stack(["price","stock"])
arr
# Out:
# array([['price', 'stock']], dtype='<U5')

# %%
#3
mean_price=np.mean(price)
mean_price.round(2)
# Out:
# np.float64(24879.78)

# %%
mean_stock=np.mean(stock)
mean_stock.round(2)
# Out:
# np.float64(257.4)

# %%
median_price=np.median(price)
median_price.round(2)
# Out:
# np.float64(25341.86)

# %%
median_stock=np.median(stock)
median_stock.round(2)
# Out:
# np.float64(266.0)

# %%
std_price=np.std(price)
std_price.round(2)
# Out:
# np.float64(14521.32)

# %%
std_stock=np.std(stock)
std_stock.round(2)
# Out:
# np.float64(142.53)

# %%
price_25=np.percentile(price,0.25)
price
# Out:
# np.float64(817.406775)

# %%
price_75=np.percentile(price,0.75)
price
# Out:
# np.float64(817.406775)

# %%
#4
filter=np.where(stock>price_75)
filter
# Out:
# (array([], dtype=int64),)

# %%
#5
class ValueError(Exception):
    pass

# %%
#6
def stats_products(df1):
    result={}
    return result({'mean_price':'price_Mean','mean_stock':'stock_mean',
                   'median_price':'price_mid','median_stock':'stock_mid',
                   'std_price':'price_std','std_stock':'stock_std'})

# %% [markdown]
# # Question 5 [12 Marks]
# ## Problem Statement:
# ### Design and implement an object-oriented solution with inheritance:
# #### Base Class Transaction:
# ##### •	Private attributes: __sale_id, __amount, __date
# ##### •	Public properties (getters/setters) for accessing private attributes
# ##### •	Method validate_amount() raises InvalidAmountError if amount ≤ 0
# ##### •	Method calculate_tax(rate) returns tax amount
# #### Derived Class ProductTransaction(Transaction):
# #### •	Inherits from Transaction
# #### •	Additional attributes: product_id, quantity
# #### •	Override __str__() method to include product details
# #### •	Method calculate_unit_price() returns amount/quantity
# #### •	Method get_transaction_summary() returns formatted string
# #### Implementation Requirements:
# #### 1.	Define custom exception InvalidAmountError and InvalidTransactionError
# #### 2.	Encapsulate all attributes with private scope
# #### 3.	Implement property decorators for safe access
# #### 4.	Read Sales.csv and create ProductTransaction objects
# #### 5.	Use try-except-finally in constructor for error handling
# #### 6.	Validate each transaction during creation
# #### 7.	Count and report valid vs invalid transactions

# %%
class InvalidAmountError(Exception):
    pass
class InvalidTransactionError(Exception):
    pass

# %%
class Transaction:
    def __init__(self,__sale_id,__amount,__date):
        self.__sale_id=sale_id
        self.__amount=amount
        self._date=date
    def get_sale_id(self):
        return self.__sale_id
    def get_amount(self):
        return self.__amount
    def get_date(self):
        return self.__date
    def validate_amount(amount):
        if df1['SaleAmount']<=0:
            print("SaleAmount is Success")
        else:
            raise InvalidAmountError(f" SaleAmount is more than zero")
    def calculate_tax(rate):
        return self._amount

# %%
class ProductTransaction(Transaction):
    def __init__(self,product_id,quantity):
        self.product_id=product_id
        self.quantity=quantity
        super().__init__()
    def calculate_unit_price(quantity):
        return self.quantity
    def get_transaction_summary(amount):
        return f"Total Transaction: {amount} is valid"

# %% [markdown]
# # Question 6  [12 Marks]
# ## Problem Statement:
# ### Implement comprehensive data integration and analysis:
# ### 1.	Load all three datasets into Pandas DataFrames
# ### 2.	Merge operations:
# #### o	Merge Sales.csv with Product.csv on ProductID
# #### 	Merge result with SalesChurn.csv on CustomerID (left join strategy)
# ### 3.	Create derived columns:
# #### o	revenue_per_unit = SaleAmount / QuantitySold
# #### o	risk_adjusted_value = CustomerValue × ChurnProbability
# ### 4.	Data filtering:
# #### o	Filter for Region == 'South' AND ChurnStatus == 'At Risk'
# ### 5.	Aggregation:
# #### o	Group by Category
# #### o	Calculate: total_revenue, avg_rating, customer_count
# ### 6.	Sorting and output:
# #### o	Sort by total_revenue in descending order
# #### o	Display top 5 categories
# ### 7.	Error handling:
# #### o	Catch KeyError for missing columns
# #### o	Handle merge-related exceptions
# #### o	Validate row counts at each operation

# %%
df3=pd.read_csv("Product(in).csv")
print(df3)
df4=pd.read_csv("Sales(in).csv")
print(df4)
df5=pd.read_csv("SalesChurn(in).csv")
print(df5)
# Out:
#       ProductID   ProductName         Category     Price  StockQuantity  \
# 0          2001  Product_2001      Accessories  19039.74            256
# 1          2002  Product_2002      Electronics  47560.36            278
# 2          2003  Product_2003      Electronics  36733.70            150
# 3          2004  Product_2004      Accessories  30133.59            283
# 4          2005  Product_2005        Wearables   8222.92            425
# ...         ...           ...              ...       ...            ...
# 1045       3046  Product_3046    Smart Devices  30985.23            118
# 1046       3047  Product_3047      Electronics  12031.49             45
# 1047       3048  Product_3048      Accessories   1707.84            241
# 1048       3049  Product_3049  Home Appliances  43569.89            238
# 1049       3050  Product_3050        Wearables   1552.84            362
#
#       SupplierID  WarrantyMonths  Rating
# 0             36              12     3.6
# 1              3              12     4.9
# 2              9               6     4.3
# 3              8              12     2.5
# 4             33               6     3.4
# ...          ...             ...     ...
# 1045          41               6     2.2
# 1046           1              12     3.3
# 1047           8               6     2.3
# 1048          23              24     3.8
# 1049          38              24     4.8
#
# [1050 rows x 8 columns]
#       SaleID   SaleDate CustomerID  ProductID  QuantitySold  SaleAmount  \
# 0       5001   7/4/2024  CUST_6438       2179             3    83085.91
# 1       5002  4/22/2024  CUST_5476       2900             1    51306.03
# 2       5003  9/16/2024  CUST_3039       2241             3    62403.89
# 3       5004  2/10/2022  CUST_7029       2486             3    48296.47
# 4       5005  5/21/2023  CUST_8159       2430             4    48337.73
# ...      ...        ...        ...        ...           ...         ...
# 1095    6096  8/17/2024  CUST_5877       2700             7    11260.04
# 1096    6097  1/27/2022  CUST_1528       2728             9    70538.13
# 1097    6098   8/9/2022  CUST_8368       2598             5    30646.31
# 1098    6099   1/2/2023  CUST_5305       2766             2    27616.83
# 1099    6100   4/8/2021  CUST_6711       2218             7    99799.77
#
#      PaymentMethod   Region
# 0      Credit Card    South
# 1       Debit Card     West
# 2      Net Banking     West
# 3       Debit Card    South
# 4      Net Banking    North
# ...            ...      ...
# 1095    Debit Card  Central
# 1096           UPI    South
# 1097   Net Banking     West
# 1098   Credit Card  Central
# 1099   Credit Card     West
#
# [1100 rows x 8 columns]
#      CustomerID LastPurchaseDate  InactiveDays  ChurnProbability  \
# 0     CUST_8373       12/17/2023            60              0.18
# 1     CUST_7303        12/2/2020           261              0.89
# 2     CUST_6821        10/3/2022           311              0.44
# 3     CUST_4698         6/1/2022            58              0.14
# 4     CUST_4044        10/2/2020           224              0.76
# ...         ...              ...           ...               ...
# 1015  CUST_8531        9/14/2023           161              0.82
# 1016  CUST_1589       11/30/2022            66              0.89
# 1017  CUST_1538        8/28/2021           161              0.52
# 1018  CUST_3897         5/8/2022           106              0.57
# 1019  CUST_5965         4/3/2022           118              0.67
#
#       CustomerValue  PurchaseFrequency ChurnStatus
# 0          48088.43                  5     Churned
# 1          30332.16                  9     Churned
# 2          28194.03                 46     Churned
# 3           1219.44                 40     At Risk
# 4           4507.01                 14     Churned
# ...             ...                ...         ...
# 1015       24777.10                 20      Active
# 1016        2334.07                 48     Churned
# 1017       26995.01                 48      Active
# 1018       35387.38                 48      Active
# 1019       17288.64                 46      Active
#
# [1020 rows x 7 columns]

# %%
#2
merge_df=df3.merge(df4,on='ProductID',how='inner')
merge_df
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1095       3047  Product_3047  Electronics  12031.49             45
# 1096       3048  Product_3048  Accessories   1707.84            241
# 1097       3048  Product_3048  Accessories   1707.84            241
# 1098       3048  Product_3048  Accessories   1707.84            241
# 1099       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate CustomerID  \
# 0             36              12     3.6    6077   7/17/2024  CUST_9808
# 1              3              12     4.9    5072  11/21/2024  CUST_9176
# 2              3              12     4.9    5471   9/27/2021  CUST_7813
# 3              9               6     4.3    5092   4/22/2021  CUST_2063
# 4              9               6     4.3    5293    1/6/2023  CUST_8775
# ...          ...             ...     ...     ...         ...        ...
# 1095           1              12     3.3    5228   7/21/2021  CUST_9108
# 1096           8               6     2.3    5188  10/26/2023  CUST_3142
# 1097           8               6     2.3    5779   8/19/2023  CUST_7525
# 1098           8               6     2.3    5944   2/13/2022  CUST_5239
# 1099           8               6     2.3    5971   4/20/2021  CUST_6706
#
#       QuantitySold  SaleAmount PaymentMethod Region
# 0                1    29654.20   Net Banking   East
# 1                6     1379.88          Cash   West
# 2                7    47752.60   Credit Card  South
# 3                7    31907.00   Credit Card   West
# 4                6    35240.03    Debit Card   West
# ...            ...         ...           ...    ...
# 1095             4    18780.38    Debit Card  South
# 1096             3    71466.02    Debit Card  South
# 1097             7    63556.14   Credit Card   East
# 1098             4    68209.85   Credit Card  South
# 1099             1    25127.11          Cash   East
#
# [1100 rows x 15 columns]

# %%
merge_result=merge_df.merge(df5,on='CustomerID',how='left')
merge_result
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1102       3047  Product_3047  Electronics  12031.49             45
# 1103       3048  Product_3048  Accessories   1707.84            241
# 1104       3048  Product_3048  Accessories   1707.84            241
# 1105       3048  Product_3048  Accessories   1707.84            241
# 1106       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ...  \
# 0             36              12     3.6    6077   7/17/2024  ...
# 1              3              12     4.9    5072  11/21/2024  ...
# 2              3              12     4.9    5471   9/27/2021  ...
# 3              9               6     4.3    5092   4/22/2021  ...
# 4              9               6     4.3    5293    1/6/2023  ...
# ...          ...             ...     ...     ...         ...  ...
# 1102           1              12     3.3    5228   7/21/2021  ...
# 1103           8               6     2.3    5188  10/26/2023  ...
# 1104           8               6     2.3    5779   8/19/2023  ...
# 1105           8               6     2.3    5944   2/13/2022  ...
# 1106           8               6     2.3    5971   4/20/2021  ...
#
#      QuantitySold  SaleAmount  PaymentMethod Region LastPurchaseDate  \
# 0               1    29654.20    Net Banking   East              NaN
# 1               6     1379.88           Cash   West              NaN
# 2               7    47752.60    Credit Card  South              NaN
# 3               7    31907.00    Credit Card   West              NaN
# 4               6    35240.03     Debit Card   West         1/2/2023
# ...           ...         ...            ...    ...              ...
# 1102            4    18780.38     Debit Card  South              NaN
# 1103            3    71466.02     Debit Card  South              NaN
# 1104            7    63556.14    Credit Card   East              NaN
# 1105            4    68209.85    Credit Card  South              NaN
# 1106            1    25127.11           Cash   East              NaN
#
#      InactiveDays  ChurnProbability  CustomerValue  PurchaseFrequency  \
# 0             NaN               NaN            NaN                NaN
# 1             NaN               NaN            NaN                NaN
# 2             NaN               NaN            NaN                NaN
# 3             NaN               NaN            NaN                NaN
# 4           198.0              0.33       19045.14               42.0
# ...           ...               ...            ...                ...
# 1102          NaN               NaN            NaN                NaN
# 1103          NaN               NaN            NaN                NaN
# 1104          NaN               NaN            NaN                NaN
# 1105          NaN               NaN            NaN                NaN
# 1106          NaN               NaN            NaN                NaN
#
#       ChurnStatus
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4         At Risk
# ...           ...
# 1102          NaN
# 1103          NaN
# 1104          NaN
# 1105          NaN
# 1106          NaN
#
# [1107 rows x 21 columns]

# %%
#3
merge_result['revenue_per_unit']=merge_result['SaleAmount']/merge_result['QuantitySold']
merge_result
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1102       3047  Product_3047  Electronics  12031.49             45
# 1103       3048  Product_3048  Accessories   1707.84            241
# 1104       3048  Product_3048  Accessories   1707.84            241
# 1105       3048  Product_3048  Accessories   1707.84            241
# 1106       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ... SaleAmount  \
# 0             36              12     3.6    6077   7/17/2024  ...   29654.20
# 1              3              12     4.9    5072  11/21/2024  ...    1379.88
# 2              3              12     4.9    5471   9/27/2021  ...   47752.60
# 3              9               6     4.3    5092   4/22/2021  ...   31907.00
# 4              9               6     4.3    5293    1/6/2023  ...   35240.03
# ...          ...             ...     ...     ...         ...  ...        ...
# 1102           1              12     3.3    5228   7/21/2021  ...   18780.38
# 1103           8               6     2.3    5188  10/26/2023  ...   71466.02
# 1104           8               6     2.3    5779   8/19/2023  ...   63556.14
# 1105           8               6     2.3    5944   2/13/2022  ...   68209.85
# 1106           8               6     2.3    5971   4/20/2021  ...   25127.11
#
#       PaymentMethod  Region LastPurchaseDate InactiveDays ChurnProbability  \
# 0       Net Banking    East              NaN          NaN              NaN
# 1              Cash    West              NaN          NaN              NaN
# 2       Credit Card   South              NaN          NaN              NaN
# 3       Credit Card    West              NaN          NaN              NaN
# 4        Debit Card    West         1/2/2023        198.0             0.33
# ...             ...     ...              ...          ...              ...
# 1102     Debit Card   South              NaN          NaN              NaN
# 1103     Debit Card   South              NaN          NaN              NaN
# 1104    Credit Card    East              NaN          NaN              NaN
# 1105    Credit Card   South              NaN          NaN              NaN
# 1106           Cash    East              NaN          NaN              NaN
#
#       CustomerValue  PurchaseFrequency  ChurnStatus  revenue_per_unit
# 0               NaN                NaN          NaN      29654.200000
# 1               NaN                NaN          NaN        229.980000
# 2               NaN                NaN          NaN       6821.800000
# 3               NaN                NaN          NaN       4558.142857
# 4          19045.14               42.0      At Risk       5873.338333
# ...             ...                ...          ...               ...
# 1102            NaN                NaN          NaN       4695.095000
# 1103            NaN                NaN          NaN      23822.006667
# 1104            NaN                NaN          NaN       9079.448571
# 1105            NaN                NaN          NaN      17052.462500
# 1106            NaN                NaN          NaN      25127.110000
#
# [1107 rows x 22 columns]

# %%
#4
filter=merge_result[merge_result['Region']=='South'] & merge_result[merge_result['ChurnStatus']=='At Risk']
filter

# %%
#5
merges=merge_result.groupby('Category').agg({'revenue_per_unit':'sum','Rating':'mean','CustomerID':'count'})
merges
# Out:
#                  revenue_per_unit    Rating  CustomerID
# Category
# Accessories          2.786500e+06  3.486869         198
# Audio                2.570085e+06  3.362011         179
# Electronics          3.672632e+06  3.444762         210
# Home Appliances      2.146936e+06  3.362195         164
# Smart Devices        3.261108e+06  3.473404         188
# Wearables            2.660933e+06  3.645833         168

# %%
sort=merge_result.sort_values(by='revenue_per_unit',ascending=False)
sort
# Out:
#       ProductID   ProductName         Category     Price  StockQuantity  \
# 346        2305  Product_2305      Electronics  36441.52            439
# 72         2072  Product_2072        Wearables  10336.43            269
# 833        2778  Product_2778      Electronics  36251.50            298
# 379        2337  Product_2337            Audio  42845.30            473
# 477        2437  Product_2437    Smart Devices   4101.77            472
# ...         ...           ...              ...       ...            ...
# 347        2305  Product_2305      Electronics  36441.52            439
# 997        2938  Product_2938      Electronics  45757.79            435
# 101        2100  Product_2100        Wearables   5840.63             29
# 932        2868  Product_2868      Electronics   9505.44            142
# 1062       3006  Product_3006  Home Appliances  33109.78            441
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ...  \
# 346            8              36     3.8    5407  11/27/2024  ...
# 72            22              24     3.4    5635  11/30/2022  ...
# 833           40              36     4.5    6020    5/7/2024  ...
# 379           32              24     3.1    5335    5/1/2023  ...
# 477           37              24     3.2    5124    8/4/2023  ...
# ...          ...             ...     ...     ...         ...  ...
# 347            8              36     3.8    6042   5/19/2021  ...
# 997           14               6     4.5    5851    8/5/2022  ...
# 101           18              12     3.2    5922    5/2/2022  ...
# 932           41               6     2.1    5646   6/19/2024  ...
# 1062          17               6     2.2    5581   5/14/2024  ...
#
#      PaymentMethod   Region  LastPurchaseDate InactiveDays ChurnProbability  \
# 346            UPI     West               NaN          NaN              NaN
# 72      Debit Card    South               NaN          NaN              NaN
# 833            UPI    North               NaN          NaN              NaN
# 379    Credit Card    North               NaN          NaN              NaN
# 477     Debit Card    North               NaN          NaN              NaN
# ...            ...      ...               ...          ...              ...
# 347            UPI    North               NaN          NaN              NaN
# 997    Credit Card  Central               NaN          NaN              NaN
# 101     Debit Card  Central               NaN          NaN              NaN
# 932     Debit Card  Central               NaN          NaN              NaN
# 1062    Debit Card    North               NaN          NaN              NaN
#
#      CustomerValue  PurchaseFrequency  ChurnStatus  revenue_per_unit  \
# 346            NaN                NaN          NaN      99684.110000
# 72             NaN                NaN          NaN      98406.730000
# 833            NaN                NaN          NaN      98243.350000
# 379            NaN                NaN          NaN      97719.590000
# 477            NaN                NaN          NaN      96248.110000
# ...            ...                ...          ...               ...
# 347            NaN                NaN          NaN        179.003333
# 997            NaN                NaN          NaN        175.717143
# 101            NaN                NaN          NaN        170.817500
# 932            NaN                NaN          NaN        150.697500
# 1062           NaN                NaN          NaN        140.901111
#
#       risk_adjusted_value
# 346                   NaN
# 72                    NaN
# 833                   NaN
# 379                   NaN
# 477                   NaN
# ...                   ...
# 347                   NaN
# 997                   NaN
# 101                   NaN
# 932                   NaN
# 1062                  NaN
#
# [1107 rows x 23 columns]

# %%
top_5=merges.head()
top_5
# Out:
#                  revenue_per_unit    Rating  CustomerID
# Category
# Accessories          2.786500e+06  3.486869         198
# Audio                2.570085e+06  3.362011         179
# Electronics          3.672632e+06  3.444762         210
# Home Appliances      2.146936e+06  3.362195         164
# Smart Devices        3.261108e+06  3.473404         188

# %% [markdown]
# # Question 7 [12 Marks]
# ## Problem Statement:
# ### Create comprehensive product visualizations using Matplotlib and Seaborn:
# ### 1.	Load Product.csv and prepare data for visualization
# ### 2.	Create 2×2 subplot layout with following charts:
# ### o	Subplot 1: Histogram of product ratings with mean line overlay
# ### o	Subplot 2: Box plot showing price distribution by category
# ### o	Subplot 3: Scatter plot of Price vs Rating with regression line
# ### o	Subplot 4: Bar plot showing product count per category
# ### 3.	Apply formatting:
# ### o	Add titles and axis labels to each subplot
# ### o	Include legends where appropriate
# ### o	Apply grid and alpha transparency for clarity
# ### 4.	Statistical analysis:
# ### o	Calculate Pearson correlation between Price and Rating
# ### o	Interpret correlation results
# ### 5.	Save visualization:
# ### o	Export final figure as PNG at 300 DPI
# ### o	Use proper figure sizing (14×10 inches)
# ### 6.	Error handling:
# ### o	Handle missing data gracefully
# ### o	Catch ValueError exceptions

# %%
df3
# Out:
#       ProductID   ProductName         Category     Price  StockQuantity  \
# 0          2001  Product_2001      Accessories  19039.74            256
# 1          2002  Product_2002      Electronics  47560.36            278
# 2          2003  Product_2003      Electronics  36733.70            150
# 3          2004  Product_2004      Accessories  30133.59            283
# 4          2005  Product_2005        Wearables   8222.92            425
# ...         ...           ...              ...       ...            ...
# 1045       3046  Product_3046    Smart Devices  30985.23            118
# 1046       3047  Product_3047      Electronics  12031.49             45
# 1047       3048  Product_3048      Accessories   1707.84            241
# 1048       3049  Product_3049  Home Appliances  43569.89            238
# 1049       3050  Product_3050        Wearables   1552.84            362
#
#       SupplierID  WarrantyMonths  Rating
# 0             36              12     3.6
# 1              3              12     4.9
# 2              9               6     4.3
# 3              8              12     2.5
# 4             33               6     3.4
# ...          ...             ...     ...
# 1045          41               6     2.2
# 1046           1              12     3.3
# 1047           8               6     2.3
# 1048          23              24     3.8
# 1049          38              24     4.8
#
# [1050 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig,axes=plt.subplots(2,2,figsize=(14,10))

plt.hist(data=df3,x='Rating',hue='Region',kde=True)
axes[0,0].set_title('Product Ratings')

sns.boxplot(data=df3,x='Price',y='Category')
axes[0,1].set_title('price Distribution by Category')

sns.scatterplot(data=df3,x='Price',y='Rating')
axes[1,0].set_title('Price vs Rating')

sns.barplot(data=df3,x='ProductID',y='Category')
axes[1,1].set_title('Product count per category')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 fig,axes=plt.subplots(2,2,figsize=(14,10))
# ----> 3 plt.hist(data=df3,x='Rating',hue='Region',kde=True)
#       4 axes[0,0].set_title('Product Ratings')
#       6 sns.boxplot(data=df3,x='Price',y='Category')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3469, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3444 @_copy_docstring_and_deprecators(Axes.hist)
#    3445 def hist(
#    3446     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#    3472         range=range,
#    3473         density=density,
#    3474         weights=weights,
#    3475         cumulative=cumulative,
#    3476         bottom=bottom,
#    3477         histtype=histtype,
#    3478         align=align,
#    3479         orientation=orientation,
#    3480         rwidth=rwidth,
#    3481         log=log,
#    3482         color=color,
#    3483         label=label,
#    3484         stacked=stacked,
#    3485         **({"data": data} if data is not None else {}),
#    3486         **kwargs,
#    3487     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1550, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1546 if label_namer and "label" not in args_and_kwargs:
#    1547     new_kwargs["label"] = _label_from_arg(
#    1548         args_and_kwargs.get(label_namer), auto_label)
# -> 1550 return func(*new_args, **new_kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:7266, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7258 p = patch[0]
#    7259 kwargs.update({
#    7260     'hatch': next(hatches),
#    7261     'linewidth': next(linewidths),
#    (...)
#    7264     'facecolor': next(facecolors),
#    7265 })
# -> 7266 p._internal_update(kwargs)
#    7267 if lbl is not None:
#    7268     p.set_label(lbl)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'hue'

# %%
#4
price_cr=df3['Price'].to_numpy()
rate_cr=df3['Rating'].to_numpy()
correlation=np.corrcoef(price_cr,rate_cr)
correlation
# Out:
# array([[ 1.        , -0.05376778],
#        [-0.05376778,  1.        ]])

# %% [markdown]
# # Question 10 [10 Marks]
# # Problem Statement:
# ## Create an integrated data analysis pipeline combining all datasets with advanced visualizations:
# ### Requirements:
# ### 1.	Data Integration:
# #### o	Load all three datasets
# #### o	Merge Sales + Product (inner join on ProductID)
# #### o	Merge result + Churn (left join on CustomerID)
# #### o	Report data quality (merged records / total records)
# #### 2.	Composite Metrics:
# #### o	market_share – product's proportion of total sales
# #### o	lifetime_value – CustomerValue × PurchaseFrequency
# #### o	risk_index – ChurnProbability × (1 – Rating/5) × (InactiveDays/365)
# #### 3.	Customer Segmentation:
# #### o	Create segments based on CustomerValue quartiles
# #### o	Flag high-risk customers (ChurnProbability > 0.6)
# #### 4.	Statistical Analysis:
# #### o	Calculate Pearson correlations:
# #### 	Price vs ChurnProbability
# #### 	Rating vs ChurnProbability
# #### 	CustomerValue vs ChurnProbability
# #### 5.	Visualizations (4 types):
# #### o	Heatmap: Risk Index by Category and Churn Status
# #### o	Dual-axis plot: Revenue vs Churn by Category
# #### o	KDE plot: Customer Value distribution by Churn Status
# #### o	Correlation heatmap: Key variables correlation matrix
# #### 6.	Recommendations:
# #### o	Identify high-risk products (top 20% risk_index)
# #### o	Export recommendations to CSV
# #### 7.	Error handling:
# #### o	Try-except-finally pattern
# #### o	Meaningful error messages

# %%
#1
df3=pd.read_csv("Product(in).csv")
print(df3)
df4=pd.read_csv("Sales(in).csv")
print(df4)
df5=pd.read_csv("SalesChurn(in).csv")
print(df5)
# Out:
#       ProductID   ProductName         Category     Price  StockQuantity  \
# 0          2001  Product_2001      Accessories  19039.74            256
# 1          2002  Product_2002      Electronics  47560.36            278
# 2          2003  Product_2003      Electronics  36733.70            150
# 3          2004  Product_2004      Accessories  30133.59            283
# 4          2005  Product_2005        Wearables   8222.92            425
# ...         ...           ...              ...       ...            ...
# 1045       3046  Product_3046    Smart Devices  30985.23            118
# 1046       3047  Product_3047      Electronics  12031.49             45
# 1047       3048  Product_3048      Accessories   1707.84            241
# 1048       3049  Product_3049  Home Appliances  43569.89            238
# 1049       3050  Product_3050        Wearables   1552.84            362
#
#       SupplierID  WarrantyMonths  Rating
# 0             36              12     3.6
# 1              3              12     4.9
# 2              9               6     4.3
# 3              8              12     2.5
# 4             33               6     3.4
# ...          ...             ...     ...
# 1045          41               6     2.2
# 1046           1              12     3.3
# 1047           8               6     2.3
# 1048          23              24     3.8
# 1049          38              24     4.8
#
# [1050 rows x 8 columns]
#       SaleID   SaleDate CustomerID  ProductID  QuantitySold  SaleAmount  \
# 0       5001   7/4/2024  CUST_6438       2179             3    83085.91
# 1       5002  4/22/2024  CUST_5476       2900             1    51306.03
# 2       5003  9/16/2024  CUST_3039       2241             3    62403.89
# 3       5004  2/10/2022  CUST_7029       2486             3    48296.47
# 4       5005  5/21/2023  CUST_8159       2430             4    48337.73
# ...      ...        ...        ...        ...           ...         ...
# 1095    6096  8/17/2024  CUST_5877       2700             7    11260.04
# 1096    6097  1/27/2022  CUST_1528       2728             9    70538.13
# 1097    6098   8/9/2022  CUST_8368       2598             5    30646.31
# 1098    6099   1/2/2023  CUST_5305       2766             2    27616.83
# 1099    6100   4/8/2021  CUST_6711       2218             7    99799.77
#
#      PaymentMethod   Region
# 0      Credit Card    South
# 1       Debit Card     West
# 2      Net Banking     West
# 3       Debit Card    South
# 4      Net Banking    North
# ...            ...      ...
# 1095    Debit Card  Central
# 1096           UPI    South
# 1097   Net Banking     West
# 1098   Credit Card  Central
# 1099   Credit Card     West
#
# [1100 rows x 8 columns]
#      CustomerID LastPurchaseDate  InactiveDays  ChurnProbability  \
# 0     CUST_8373       12/17/2023            60              0.18
# 1     CUST_7303        12/2/2020           261              0.89
# 2     CUST_6821        10/3/2022           311              0.44
# 3     CUST_4698         6/1/2022            58              0.14
# 4     CUST_4044        10/2/2020           224              0.76
# ...         ...              ...           ...               ...
# 1015  CUST_8531        9/14/2023           161              0.82
# 1016  CUST_1589       11/30/2022            66              0.89
# 1017  CUST_1538        8/28/2021           161              0.52
# 1018  CUST_3897         5/8/2022           106              0.57
# 1019  CUST_5965         4/3/2022           118              0.67
#
#       CustomerValue  PurchaseFrequency ChurnStatus
# 0          48088.43                  5     Churned
# 1          30332.16                  9     Churned
# 2          28194.03                 46     Churned
# 3           1219.44                 40     At Risk
# 4           4507.01                 14     Churned
# ...             ...                ...         ...
# 1015       24777.10                 20      Active
# 1016        2334.07                 48     Churned
# 1017       26995.01                 48      Active
# 1018       35387.38                 48      Active
# 1019       17288.64                 46      Active
#
# [1020 rows x 7 columns]

# %%
merge_df=df3.merge(df4,on='ProductID',how='inner')
merge_df
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1095       3047  Product_3047  Electronics  12031.49             45
# 1096       3048  Product_3048  Accessories   1707.84            241
# 1097       3048  Product_3048  Accessories   1707.84            241
# 1098       3048  Product_3048  Accessories   1707.84            241
# 1099       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate CustomerID  \
# 0             36              12     3.6    6077   7/17/2024  CUST_9808
# 1              3              12     4.9    5072  11/21/2024  CUST_9176
# 2              3              12     4.9    5471   9/27/2021  CUST_7813
# 3              9               6     4.3    5092   4/22/2021  CUST_2063
# 4              9               6     4.3    5293    1/6/2023  CUST_8775
# ...          ...             ...     ...     ...         ...        ...
# 1095           1              12     3.3    5228   7/21/2021  CUST_9108
# 1096           8               6     2.3    5188  10/26/2023  CUST_3142
# 1097           8               6     2.3    5779   8/19/2023  CUST_7525
# 1098           8               6     2.3    5944   2/13/2022  CUST_5239
# 1099           8               6     2.3    5971   4/20/2021  CUST_6706
#
#       QuantitySold  SaleAmount PaymentMethod Region
# 0                1    29654.20   Net Banking   East
# 1                6     1379.88          Cash   West
# 2                7    47752.60   Credit Card  South
# 3                7    31907.00   Credit Card   West
# 4                6    35240.03    Debit Card   West
# ...            ...         ...           ...    ...
# 1095             4    18780.38    Debit Card  South
# 1096             3    71466.02    Debit Card  South
# 1097             7    63556.14   Credit Card   East
# 1098             4    68209.85   Credit Card  South
# 1099             1    25127.11          Cash   East
#
# [1100 rows x 15 columns]

# %%
merge_result=merge_df.merge(df5,on='CustomerID',how='left')
merge_result
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1102       3047  Product_3047  Electronics  12031.49             45
# 1103       3048  Product_3048  Accessories   1707.84            241
# 1104       3048  Product_3048  Accessories   1707.84            241
# 1105       3048  Product_3048  Accessories   1707.84            241
# 1106       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ...  \
# 0             36              12     3.6    6077   7/17/2024  ...
# 1              3              12     4.9    5072  11/21/2024  ...
# 2              3              12     4.9    5471   9/27/2021  ...
# 3              9               6     4.3    5092   4/22/2021  ...
# 4              9               6     4.3    5293    1/6/2023  ...
# ...          ...             ...     ...     ...         ...  ...
# 1102           1              12     3.3    5228   7/21/2021  ...
# 1103           8               6     2.3    5188  10/26/2023  ...
# 1104           8               6     2.3    5779   8/19/2023  ...
# 1105           8               6     2.3    5944   2/13/2022  ...
# 1106           8               6     2.3    5971   4/20/2021  ...
#
#      QuantitySold  SaleAmount  PaymentMethod Region LastPurchaseDate  \
# 0               1    29654.20    Net Banking   East              NaN
# 1               6     1379.88           Cash   West              NaN
# 2               7    47752.60    Credit Card  South              NaN
# 3               7    31907.00    Credit Card   West              NaN
# 4               6    35240.03     Debit Card   West         1/2/2023
# ...           ...         ...            ...    ...              ...
# 1102            4    18780.38     Debit Card  South              NaN
# 1103            3    71466.02     Debit Card  South              NaN
# 1104            7    63556.14    Credit Card   East              NaN
# 1105            4    68209.85    Credit Card  South              NaN
# 1106            1    25127.11           Cash   East              NaN
#
#      InactiveDays  ChurnProbability  CustomerValue  PurchaseFrequency  \
# 0             NaN               NaN            NaN                NaN
# 1             NaN               NaN            NaN                NaN
# 2             NaN               NaN            NaN                NaN
# 3             NaN               NaN            NaN                NaN
# 4           198.0              0.33       19045.14               42.0
# ...           ...               ...            ...                ...
# 1102          NaN               NaN            NaN                NaN
# 1103          NaN               NaN            NaN                NaN
# 1104          NaN               NaN            NaN                NaN
# 1105          NaN               NaN            NaN                NaN
# 1106          NaN               NaN            NaN                NaN
#
#       ChurnStatus
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4         At Risk
# ...           ...
# 1102          NaN
# 1103          NaN
# 1104          NaN
# 1105          NaN
# 1106          NaN
#
# [1107 rows x 21 columns]

# %%
merge_result['revenue_per_unit']=merge_result['SaleAmount']/merge_result['QuantitySold']
merge_result.head(10)
# Out:
#    ProductID   ProductName         Category     Price  StockQuantity  \
# 0       2001  Product_2001      Accessories  19039.74            256
# 1       2002  Product_2002      Electronics  47560.36            278
# 2       2002  Product_2002      Electronics  47560.36            278
# 3       2003  Product_2003      Electronics  36733.70            150
# 4       2003  Product_2003      Electronics  36733.70            150
# 5       2003  Product_2003      Electronics  36733.70            150
# 6       2004  Product_2004      Accessories  30133.59            283
# 7       2005  Product_2005        Wearables   8222.92            425
# 8       2006  Product_2006  Home Appliances   8221.73            105
# 9       2006  Product_2006  Home Appliances   8221.73            105
#
#    SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ... SaleAmount  \
# 0          36              12     3.6    6077   7/17/2024  ...   29654.20
# 1           3              12     4.9    5072  11/21/2024  ...    1379.88
# 2           3              12     4.9    5471   9/27/2021  ...   47752.60
# 3           9               6     4.3    5092   4/22/2021  ...   31907.00
# 4           9               6     4.3    5293    1/6/2023  ...   35240.03
# 5           9               6     4.3    5531   11/2/2023  ...   70843.51
# 6           8              12     2.5    5505    4/3/2023  ...   95628.47
# 7          33               6     3.4    6095   3/16/2021  ...   37245.20
# 8           6               6     4.2    5046   10/8/2024  ...    9620.05
# 9           6               6     4.2    5240   8/24/2022  ...   98136.97
#
#    PaymentMethod   Region LastPurchaseDate InactiveDays ChurnProbability  \
# 0    Net Banking     East              NaN          NaN              NaN
# 1           Cash     West              NaN          NaN              NaN
# 2    Credit Card    South              NaN          NaN              NaN
# 3    Credit Card     West              NaN          NaN              NaN
# 4     Debit Card     West         1/2/2023        198.0             0.33
# 5            UPI     West              NaN          NaN              NaN
# 6     Debit Card  Central              NaN          NaN              NaN
# 7     Debit Card     West              NaN          NaN              NaN
# 8    Net Banking    South              NaN          NaN              NaN
# 9    Credit Card     West              NaN          NaN              NaN
#
#    CustomerValue  PurchaseFrequency  ChurnStatus  revenue_per_unit
# 0            NaN                NaN          NaN      29654.200000
# 1            NaN                NaN          NaN        229.980000
# 2            NaN                NaN          NaN       6821.800000
# 3            NaN                NaN          NaN       4558.142857
# 4       19045.14               42.0      At Risk       5873.338333
# 5            NaN                NaN          NaN      10120.501429
# 6            NaN                NaN          NaN      13661.210000
# 7            NaN                NaN          NaN       9311.300000
# 8            NaN                NaN          NaN       1202.506250
# 9            NaN                NaN          NaN      24534.242500
#
# [10 rows x 22 columns]

# %%
#2
merge_result['lifetime_value']=merge_result['CustomerValue']*merge_result['PurchaseFrequency']
merge_result
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1102       3047  Product_3047  Electronics  12031.49             45
# 1103       3048  Product_3048  Accessories   1707.84            241
# 1104       3048  Product_3048  Accessories   1707.84            241
# 1105       3048  Product_3048  Accessories   1707.84            241
# 1106       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ...  \
# 0             36              12     3.6    6077   7/17/2024  ...
# 1              3              12     4.9    5072  11/21/2024  ...
# 2              3              12     4.9    5471   9/27/2021  ...
# 3              9               6     4.3    5092   4/22/2021  ...
# 4              9               6     4.3    5293    1/6/2023  ...
# ...          ...             ...     ...     ...         ...  ...
# 1102           1              12     3.3    5228   7/21/2021  ...
# 1103           8               6     2.3    5188  10/26/2023  ...
# 1104           8               6     2.3    5779   8/19/2023  ...
# 1105           8               6     2.3    5944   2/13/2022  ...
# 1106           8               6     2.3    5971   4/20/2021  ...
#
#      PaymentMethod  Region  LastPurchaseDate InactiveDays ChurnProbability  \
# 0      Net Banking    East               NaN          NaN              NaN
# 1             Cash    West               NaN          NaN              NaN
# 2      Credit Card   South               NaN          NaN              NaN
# 3      Credit Card    West               NaN          NaN              NaN
# 4       Debit Card    West          1/2/2023        198.0             0.33
# ...            ...     ...               ...          ...              ...
# 1102    Debit Card   South               NaN          NaN              NaN
# 1103    Debit Card   South               NaN          NaN              NaN
# 1104   Credit Card    East               NaN          NaN              NaN
# 1105   Credit Card   South               NaN          NaN              NaN
# 1106          Cash    East               NaN          NaN              NaN
#
#      CustomerValue  PurchaseFrequency  ChurnStatus  revenue_per_unit  \
# 0              NaN                NaN          NaN      29654.200000
# 1              NaN                NaN          NaN        229.980000
# 2              NaN                NaN          NaN       6821.800000
# 3              NaN                NaN          NaN       4558.142857
# 4         19045.14               42.0      At Risk       5873.338333
# ...            ...                ...          ...               ...
# 1102           NaN                NaN          NaN       4695.095000
# 1103           NaN                NaN          NaN      23822.006667
# 1104           NaN                NaN          NaN       9079.448571
# 1105           NaN                NaN          NaN      17052.462500
# 1106           NaN                NaN          NaN      25127.110000
#
#       lifetime_value
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4          799895.88
# ...              ...
# 1102             NaN
# 1103             NaN
# 1104             NaN
# 1105             NaN
# 1106             NaN
#
# [1107 rows x 23 columns]

# %%
merge_result['risk_index']=merge_result['ChurnProbability']*(1-merge_result['Rating']/5)*merge_result['InactiveDays']/365
merge_result
# Out:
#       ProductID   ProductName     Category     Price  StockQuantity  \
# 0          2001  Product_2001  Accessories  19039.74            256
# 1          2002  Product_2002  Electronics  47560.36            278
# 2          2002  Product_2002  Electronics  47560.36            278
# 3          2003  Product_2003  Electronics  36733.70            150
# 4          2003  Product_2003  Electronics  36733.70            150
# ...         ...           ...          ...       ...            ...
# 1102       3047  Product_3047  Electronics  12031.49             45
# 1103       3048  Product_3048  Accessories   1707.84            241
# 1104       3048  Product_3048  Accessories   1707.84            241
# 1105       3048  Product_3048  Accessories   1707.84            241
# 1106       3048  Product_3048  Accessories   1707.84            241
#
#       SupplierID  WarrantyMonths  Rating  SaleID    SaleDate  ... Region  \
# 0             36              12     3.6    6077   7/17/2024  ...   East
# 1              3              12     4.9    5072  11/21/2024  ...   West
# 2              3              12     4.9    5471   9/27/2021  ...  South
# 3              9               6     4.3    5092   4/22/2021  ...   West
# 4              9               6     4.3    5293    1/6/2023  ...   West
# ...          ...             ...     ...     ...         ...  ...    ...
# 1102           1              12     3.3    5228   7/21/2021  ...  South
# 1103           8               6     2.3    5188  10/26/2023  ...  South
# 1104           8               6     2.3    5779   8/19/2023  ...   East
# 1105           8               6     2.3    5944   2/13/2022  ...  South
# 1106           8               6     2.3    5971   4/20/2021  ...   East
#
#       LastPurchaseDate  InactiveDays ChurnProbability CustomerValue  \
# 0                  NaN           NaN              NaN           NaN
# 1                  NaN           NaN              NaN           NaN
# 2                  NaN           NaN              NaN           NaN
# 3                  NaN           NaN              NaN           NaN
# 4             1/2/2023         198.0             0.33      19045.14
# ...                ...           ...              ...           ...
# 1102               NaN           NaN              NaN           NaN
# 1103               NaN           NaN              NaN           NaN
# 1104               NaN           NaN              NaN           NaN
# 1105               NaN           NaN              NaN           NaN
# 1106               NaN           NaN              NaN           NaN
#
#      PurchaseFrequency  ChurnStatus  revenue_per_unit  lifetime_value  \
# 0                  NaN          NaN      29654.200000             NaN
# 1                  NaN          NaN        229.980000             NaN
# 2                  NaN          NaN       6821.800000             NaN
# 3                  NaN          NaN       4558.142857             NaN
# 4                 42.0      At Risk       5873.338333       799895.88
# ...                ...          ...               ...             ...
# 1102               NaN          NaN       4695.095000             NaN
# 1103               NaN          NaN      23822.006667             NaN
# 1104               NaN          NaN       9079.448571             NaN
# 1105               NaN          NaN      17052.462500             NaN
# 1106               NaN          NaN      25127.110000             NaN
#
#       risk_index
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4       0.025062
# ...          ...
# 1102         NaN
# 1103         NaN
# 1104         NaN
# 1105         NaN
# 1106         NaN
#
# [1107 rows x 24 columns]

# %%
#3
def CustomerValue(merge_result):
    if merge_result['ChurnProbability']>0.6:
        print('High Risk')
    else:
        print('Low Risk')
