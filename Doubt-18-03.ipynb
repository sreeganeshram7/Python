# %% [markdown]
# ## Design a data pipeline for cleaning and analyzing a real world csv dataset what are the steps potential issue and how would you handle it?

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("assignment1_sales_data.csv")
df.head()
# Out:
#    ProductID ProductName     Category Region  Q1Sales  Q2Sales  Q3Sales  \
# 0        101       Mouse  Electronics   East      868      430      101
# 1        102  Headphones  Electronics  North      104      739      741
# 2        103    Keyboard  Accessories  North      317      605      319
# 3        104     Speaker  Electronics  North      602      447      665
# 4        105       Mouse  Accessories   East      866      572      954
#
#    Q4Sales  UnitPrice  TotalSales
# 0      810       1299        2209
# 1      919        599        2503
# 2      588         19        1829
# 3      739         79        2453
# 4      650         19        3042

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    50 non-null     int64
#  1   ProductName  50 non-null     object
#  2   Category     50 non-null     object
#  3   Region       50 non-null     object
#  4   Q1Sales      50 non-null     int64
#  5   Q2Sales      50 non-null     int64
#  6   Q3Sales      50 non-null     int64
#  7   Q4Sales      50 non-null     int64
#  8   UnitPrice    50 non-null     int64
#  9   TotalSales   50 non-null     int64
# dtypes: int64(7), object(3)
# memory usage: 4.0+ KB

# %%
df.dtypes
# Out:
# ProductID       int64
# ProductName    object
# Category       object
# Region         object
# Q1Sales         int64
# Q2Sales         int64
# Q3Sales         int64
# Q4Sales         int64
# UnitPrice       int64
# TotalSales      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ProductID      0
# ProductName    0
# Category       0
# Region         0
# Q1Sales        0
# Q2Sales        0
# Q3Sales        0
# Q4Sales        0
# UnitPrice      0
# TotalSales     0
# dtype: int64

# %% [markdown]
# lower_bound = Q1 - 1.5 * IQR
#
# upper_bound = Q3 + 1.5 * IQR
#
# Q1 = df['Amount'].quantile(0.25)
#
# Q3 = df['Amount'].quantile(0.75)
#
# IQR = Q3 - Q1
